# %%
import numpy as np 
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('USA_Housing.csv')

# %%
df.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %%
df['Avg. Number of Bedrooms']=df['Avg. Area Number of Bedrooms']

# %%
df=df.drop('Avg. Area Number of Bedrooms',axis=1)

# %%
df.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Area Population         Price  \
# 0     23086.800503  1.059034e+06
# 1     40173.072174  1.505891e+06
# 2     36882.159400  1.058988e+06
# 3     34310.242831  1.260617e+06
# 4     26354.109472  6.309435e+05
#
#                                              Address  Avg. Number of Bedrooms
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...                     4.09
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...                     3.09
# 2  9127 Elizabeth Stravenue\nDanieltown, WI 06482...                     5.13
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Avg. Area Income           5000 non-null   float64
#  1   Avg. Area House Age        5000 non-null   float64
#  2   Avg. Area Number of Rooms  5000 non-null   float64
#  3   Area Population            5000 non-null   float64
#  4   Price                      5000 non-null   float64
#  5   Address                    5000 non-null   object
#  6   Avg. Number of Bedrooms    5000 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 273.6+ KB

# %%
df.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562388             5.322283                   6.299250
# 50%        68804.286404             5.970429                   7.002902
# 75%        75783.338666             6.650808                   7.665871
# max       107701.748378             9.519088                  10.759588
#
#        Area Population         Price  Avg. Number of Bedrooms
# count      5000.000000  5.000000e+03              5000.000000
# mean      36163.516039  1.232073e+06                 3.981330
# std        9925.650114  3.531176e+05                 1.234137
# min         172.610686  1.593866e+04                 2.000000
# ...

# %%
df.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Area Population', 'Price', 'Address', 'Avg. Number of Bedrooms'],
#       dtype='object')

# %%
df=df.drop('Address',axis=1)

# %%
df.corr()
# Out:
#                            Avg. Area Income  Avg. Area House Age  \
# Avg. Area Income                   1.000000            -0.002007
# Avg. Area House Age               -0.002007             1.000000
# Avg. Area Number of Rooms         -0.011032            -0.009428
# Area Population                   -0.016234            -0.018743
# Price                              0.639734             0.452543
# Avg. Number of Bedrooms            0.019788             0.006149
#
#                            Avg. Area Number of Rooms  Area Population  \
# Avg. Area Income                           -0.011032        -0.016234
# Avg. Area House Age                        -0.009428        -0.018743
# Avg. Area Number of Rooms                   1.000000         0.002040
# Area Population                             0.002040         1.000000
# Price                                       0.335664         0.408556
# Avg. Number of Bedrooms                     0.462695        -0.022168
#
# ...

# %%
sns.pairplot(df)

# %% [markdown]
# HERE THE CORRELATION WITH THE NUMBER OF BEDROOMS IS DISPLAYING SOME NON-UNIFORMITY WHILE ALL OTHERS SIMILIARLY CO-RELATED

# %% [markdown]
# WE DO DISTPLOT ON THE TARGET USUALLY AND PAIRPLOT TO GET THE VIEW OF CORRELATION AND VIEW NON-UNIFORMITY

# %%
sns.distplot(df['Price'],bins=100)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_6416\2589050281.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price'],bins=100)
# <Axes: xlabel='Price', ylabel='Density'>

# %%
df.corr()
# Out:
#                            Avg. Area Income  Avg. Area House Age  \
# Avg. Area Income                   1.000000            -0.002007
# Avg. Area House Age               -0.002007             1.000000
# Avg. Area Number of Rooms         -0.011032            -0.009428
# Area Population                   -0.016234            -0.018743
# Price                              0.639734             0.452543
# Avg. Number of Bedrooms            0.019788             0.006149
#
#                            Avg. Area Number of Rooms  Area Population  \
# Avg. Area Income                           -0.011032        -0.016234
# Avg. Area House Age                        -0.009428        -0.018743
# Avg. Area Number of Rooms                   1.000000         0.002040
# Area Population                             0.002040         1.000000
# Price                                       0.335664         0.408556
# Avg. Number of Bedrooms                     0.462695        -0.022168
#
# ...

# %%
sns.heatmap(df.corr(),annot=True, cmap='magma')
# Out:
# <Axes: >

# %% [markdown]
# SPLITTING THE DATA INTO FEATURES AND TARGET

# %% [markdown]
# TO DO SO WE USE
# x=df[[*all the feature columns*]]
# y=df[*target column*]

# %%
df.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Area Population', 'Price', 'Avg. Number of Bedrooms'],
#       dtype='object')

# %%
x=df[['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms','Area Population', 'Avg. Number of Bedrooms']]

# %%
y=df['Price']

# %% [markdown]
# SPLITTING THE DATA INTO TRAINING AND TESTING DATASET

# %% [markdown]
# FOR SPLITTING WE NEED TO IMPORT THE scikit LIBRARY BY from sklearn.model_selection import train_test_split

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# NOW TO TRAIN WE USEx_test,x_train,y_test,y_train=train_test_split(x,y train_size=0.4*percentage for test reserved*, random_state=101*seed*)

# %%
x_test,x_train,y_test,y_train=train_test_split(x,y,train_size=0.4, random_state=101)

# %% [markdown]
# NOW WE WILL IMPORT THE LINEAR REGRESSION MODEL FROM SCIKIT USING from sklearn.linear_model import LinearRegression

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# CREATING AN OBJECT OF THAT MODEL

# %%
lm=LinearRegression()

# %% [markdown]
# NOW WE WILL FIT THE DATA INTO THE MODEL USING lm.fit(x_train, y_train)

# %%
lm.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# PRINTING THE INTERCEPT

# %%
print(lm.intercept_)
# Out:
# -2650279.1425480824

# %% [markdown]
# ACCESSING THE COFFECIENTS ASSOCIATED WITH EACH EACH FEATURE IN THE MODEL

# %%
lm.coef_
# Out:
# array([2.17073198e+01, 1.67207539e+05, 1.19990678e+05, 1.52078449e+01,
#        1.44384361e+03])

# %%
x_train.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Area Population', 'Avg. Number of Bedrooms'],
#       dtype='object')

# %%
pd.DataFrame(lm.coef_,x_test.columns, columns=['coff'])
# Out:
#                                     coff
# Avg. Area Income               21.707320
# Avg. Area House Age        167207.538815
# Avg. Area Number of Rooms  119990.677635
# Area Population                15.207845
# Avg. Number of Bedrooms      1443.843615
