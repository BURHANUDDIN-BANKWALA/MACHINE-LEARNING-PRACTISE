# %%
import pandas as pd 
import numpy as np

# %%
from plotly import __version__
print(__version__)
# Out:
# 5.24.1

# %%
import cufflinks as cf
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df=pd.DataFrame(np.random.randn(100,4),columns='A B C D'.split())

# %%
df2=pd.DataFrame({'Category':['A','B','C'],'Values':[32,43,50]})

# %%
df
# Out:
#            A         B         C         D
# 0  -0.077158  0.537408  0.528408 -0.522401
# 1  -0.312849 -0.789193 -0.214154 -0.165363
# 2  -0.375357 -0.862759  0.895180  0.896222
# 3  -0.208645 -1.307630  0.894325  0.194603
# 4  -1.051156  0.203912  0.304545  0.663720
# ..       ...       ...       ...       ...
# 95 -0.887991  0.191035  0.813250  0.478379
# 96  1.015352 -0.316342 -0.834290  0.464959
# 97  0.644973  0.086673 -0.578832  0.345270
# 98 -1.486496  0.314093 -0.738313  1.845755
# 99  0.321627  0.322978 -0.090387  1.368569
#
# [100 rows x 4 columns]

# %%
df2
# Out:
#   Category  Values
# 0        A      32
# 1        B      43
# 2        C      50

# %% [markdown]
# DUE TO USE OF PLOTLY LIBRARY IT DIRECTLY CREATES STUNNING PLOTS JUST BY USING .plot() METHOD

# %%
df.plot()
# Out:
# <Axes: >

# %% [markdown]
# TO MAKE IT MORE STUNNING WE USE .iplot() METHOD

# %%
df.iplot()
# Out:
# <div>                            <div id="86c70b65-12a9-4697-84ef-76d420aa779a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# TO CREATE SCATTER PLOT WE USE iplot(kind='scatter'x=,y=)

# %%
df.iplot(kind='scatter',x='A',y='B')
# Out:
# <div>                            <div id="1e6c23e3-864c-40e7-89cf-61a3652fda6a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='scatter',x='A',y='B', mode='markers')
# Out:
# <div>                            <div id="b4385806-7f90-44fc-9566-fb9093df0111" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# TO CHANGE THE SIZE OF THE MARKERS WE USE size=20

# %%
df.iplot(kind='scatter', x='A',y='B', mode='markers', size=20)
# Out:
# <div>                            <div id="4c71fcb5-81b3-4dab-89d5-df4bcdb21ae8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df2.iplot(kind='bar',x='Category',y='Values')
# Out:
# <div>                            <div id="4802bc88-a7a5-4ba4-b996-1741c856c92a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='bar')
# Out:
# <div>                            <div id="23db1d14-3dda-4eda-91b7-9309c2660d2f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# WE ADD SOME AGGREGATE FUNCTION BEFORE USING THE BAR ON LARGE DATAS

# %%
df.count().iplot(kind='bar')
# Out:
# <div>                            <div id="3a8fdc04-66ed-4b39-82f9-a330f587c426" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.sum().iplot(kind='bar')
# Out:
# <div>                            <div id="ca4a15a9-ca28-43a7-8761-7dc5ca0aec1b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df2.sum().iplot(kind='bar')
# Out:
# <div>                            <div id="821c87ed-7e0d-4816-85b2-f812c46c2439" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='box')
# Out:
# <div>                            <div id="ff55b72d-ac4c-41a4-9e6c-346e12c20453" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df3=pd.DataFrame({'x':[1,2,3,4,5],'y':[10,20,30,20,10],'z':[500,4000,300,200,100]})
df3.iplot(kind='surface')
# Out:
# <div>                            <div id="f340f715-6077-42d1-b004-e81c6830934f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df3=pd.DataFrame({'x':[1,2,3,4,5],'y':[10,20,30,20,10],'z':[5,4,3,2,1]})
df3.iplot(kind='surface')
# Out:
# <div>                            <div id="9d4e6316-7dfb-47f4-96d5-68e61f7d5add" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df3=pd.DataFrame({'x':[1,2,3,4,5],'y':[10,20,30,20,10],'z':[500,4000,300,200,100]})
df3.iplot(kind='surface',colorscale='rdylbu')
# Out:
# <div>                            <div id="2b68e0eb-73ab-448e-a656-281d99030200" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df['A'].iplot(kind='hist',bins=25)
df.iplot(kind='hist')
# Out:
# <div>                            <div id="c0c14bfc-5260-4933-b573-7fc491963614" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# TO USE SPREAD PLOT USE df.iplot(kind='line', fill=True)

# %%
df[['A','B']].iplot(kind='line',fill=True)
# Out:
# <div>                            <div id="46924f47-edac-4dcd-9fd7-200c17c986e3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# BUBBLE PLOT

# %%
df.iplot(kind='bubble',x='A',y='B',size='C')
# Out:
# <div>                            <div id="d11082c5-098a-4264-b2ae-86a06a342924" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.scatter_matrix(size=5)
# Out:
# <div>                            <div id="15d7bb9f-ae6a-4c52-bcbd-65c2dcb3d6d5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
