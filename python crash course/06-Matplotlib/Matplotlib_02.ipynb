# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
x=np.linspace(0,5,11)
y=x**2

# %%
fig, axes= plt.subplots()
axes.plot(x,y)
fig

# %%
fig,axes=plt.subplots(nrows=1, ncols=2)
fig

# %%
fig,axes=plt.subplots(nrows=3, ncols=3)
fig

# %%
fig,axes=plt.subplots(nrows=3, ncols=3)

plt.tight_layout()
fig

# %%
fig, axes=plt.subplots(nrows= 1,ncols=2)
axes
fig

# %%
"""fig,axes=plt.subplots(nrows=1, ncols=2)
for current_ax in axes:
    current_ax.plot(x,y)
    fig"""

# %%
fig,axes=plt.subplots(nrows=1, ncols=2)
axes[0].plot(x,y)
axes[1].plot(y,x)
fig

# %%
axes[0].plot(x,y)
axes[0].set_title("TITLE")

axes[1].plot(y,x)
axes[1].set_title('SECOND PLOT')
plt.tight_layout()
fig

# %% [markdown]
# FIGURE AND DPI

# %%
fig=plt.figure(figsize=(3,2))
##3X2 inches X inches
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
fig=plt.figure(figsize=(8,2))
ax=fig.add_axes([0,0,1,1])
ax.plot(y,x)

# %% [markdown]
# FOR SUBPLOTS

# %%
fig,axes=plt.subplots(figsize=(5,5))
axes.plot(x,y)

# %%
fig,axes=plt.subplots(nrows=2, ncols=1, figsize=(5,4))
axes[0].plot(x,y)
axes[1].plot(y,x)
plt.tight_layout()
fig.savefig('MY_PICTURES.png')
fig.savefig('JPEG_SAVE.jpeg')
fig.savefig('with_dpi',dpi=200)

# %% [markdown]
# SAVING PLOTS

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y)
ax.set_title('TITLE')
ax.set_xlabel('X')
ax.set_ylabel('Y')
# Out:
# Text(0, 0.5, 'Y')

# %% [markdown]
# LEGENDS

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,x**2)
ax.plot(x,x**3)

# %% [markdown]
# ax.legend WILL GIVE WARNING SINCE LABELS ARE NOT DEFINED

# %%
ax.legend()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_11420\1491706200.py:1: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,x**2, label='X squared')
ax.plot(x,x**3, label='X cubed')
ax.legend()

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,x**2, label='X squared')
ax.plot(x,x**3, label='X cubed')

ax.legend(loc=0)

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,x**2, label='X squared')
ax.plot(x,x**3, label='X cubed')

ax.legend(loc=1)

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,x**2, label='X squared')
ax.plot(x,x**3, label='X cubed')

ax.legend(loc=10)

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,x**2, label='X squared')
ax.plot(x,x**3, label='X cubed')

ax.legend(loc=(0.1,0.1))
